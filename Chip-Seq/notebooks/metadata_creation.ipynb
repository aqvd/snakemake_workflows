# %% [markdown]
# # Metadata Generation
#
# This notebook illustrates the process of generating metadata stored in `data` object in the Snakefile.
# Each cell adds one column to `data` following the instructions and conditions

# %%
import os
import  pandas as pd
import numpy as np
import glob
from snakemake.io import expand

# %%
data = pd.read_csv("../config/table_siNipbl_cluster.tsv", sep="\t")

# %%
## Genome bowtie2 index prefixes paths
genome_path = {
	"mm9":"/storage/scratch01/users/dgimenezl/genomes/mouse/mm9/mm9",
    "mm10":"/storage/scratch01/users/dgimenezl/genomes/mouse/mm10/mm10" ,
    "hg19":"/storage/scratch01/users/dgimenezl/genomes/human/hg19/hg19",
    "hg38":"/storage/scratch01/users/dgimenezl/genomes/human/hg38/hg38",
    "-":""}
refSeq_genes_path = {
	"mm9" : "",
	"mm10" : "",
	"hg19" : "/storage/scratch01/users/aquevedo/genomes/human/hg19/hg19_RefSeqCuratedGenes.bed",
	"hg38" : ""
}
## Genome sizes for big wig computation
genome_size={"mm9":2620345972,
    "mm10":2652783500,
    "hg19":2864785220,
    "hg38":2913022398}

# %%
## Add extra cols for salecting the appropriate wildcards path to files
data["Samples"] = data.Protein +"_"+data.Condition+"_"+ data.Rep 
data
# Out:
#    Protein Condition  Rep                   Ext  Run  \
# 0    input       siC   S9  L001_R1_001.fastq.gz  NaN
# 1    input       siC   S9  L002_R1_001.fastq.gz  NaN
# 2    input       siC   S9  L003_R1_001.fastq.gz  NaN
# 3    input       siC   S9  L004_R1_001.fastq.gz  NaN
# 4    input   siNipbl  S10  L001_R1_001.fastq.gz  NaN
# 5    input   siNipbl  S10  L002_R1_001.fastq.gz  NaN
# 6    input   siNipbl  S10  L003_R1_001.fastq.gz  NaN
# 7    input   siNipbl  S10  L004_R1_001.fastq.gz  NaN
# 8    NiPBL       siC   S4  L001_R1_001.fastq.gz  NaN
# 9    NiPBL       siC   S4  L002_R1_001.fastq.gz  NaN
# 10   NiPBL       siC   S4  L003_R1_001.fastq.gz  NaN
# 11   NiPBL       siC   S4  L004_R1_001.fastq.gz  NaN
# 12     SA1       siC   S1  L001_R1_001.fastq.gz  NaN
# 13     SA1       siC   S1  L002_R1_001.fastq.gz  NaN
# 14     SA1       siC   S1  L003_R1_001.fastq.gz  NaN
# 15     SA1       siC   S1  L004_R1_001.fastq.gz  NaN
# 16     SA2       siC  S11  L001_R1_001.fastq.gz  NaN
# 17     SA2       siC  S11  L002_R1_001.fastq.gz  NaN
# 18     SA2       siC  S11  L003_R1_001.fastq.gz  NaN
# 19     SA2       siC  S11  L004_R1_001.fastq.gz  NaN
# 20     SA2       siC   S2  L001_R1_001.fastq.gz  NaN
# 21     SA2       siC   S2  L002_R1_001.fastq.gz  NaN
# 22     SA2       siC   S2  L003_R1_001.fastq.gz  NaN
# 23     SA2       siC   S2  L004_R1_001.fastq.gz  NaN
# 24    SMC1       siC  S12  L001_R1_001.fastq.gz  NaN
# 25    SMC1       siC  S12  L002_R1_001.fastq.gz  NaN
# 26    SMC1       siC  S12  L003_R1_001.fastq.gz  NaN
# 27    SMC1       siC  S12  L004_R1_001.fastq.gz  NaN
# 28    SMC1       siC   S3  L001_R1_001.fastq.gz  NaN
# 29    SMC1       siC   S3  L002_R1_001.fastq.gz  NaN
# 30    SMC1       siC   S3  L003_R1_001.fastq.gz  NaN
# 31    SMC1       siC   S3  L004_R1_001.fastq.gz  NaN
# 32   NiPBL   siNipbl   S8  L001_R1_001.fastq.gz  NaN
# 33   NiPBL   siNipbl   S8  L002_R1_001.fastq.gz  NaN
# 34   NiPBL   siNipbl   S8  L003_R1_001.fastq.gz  NaN
# 35   NiPBL   siNipbl   S8  L004_R1_001.fastq.gz  NaN
# 36     SA1   siNipbl   S5  L001_R1_001.fastq.gz  NaN
# 37     SA1   siNipbl   S5  L002_R1_001.fastq.gz  NaN
# 38     SA1   siNipbl   S5  L003_R1_001.fastq.gz  NaN
# 39     SA1   siNipbl   S5  L004_R1_001.fastq.gz  NaN
# 40     SA2   siNipbl   S6  L001_R1_001.fastq.gz  NaN
# 41     SA2   siNipbl   S6  L002_R1_001.fastq.gz  NaN
# 42     SA2   siNipbl   S6  L003_R1_001.fastq.gz  NaN
# 43     SA2   siNipbl   S6  L004_R1_001.fastq.gz  NaN
# 44    SMC1   siNipbl   S7  L001_R1_001.fastq.gz  NaN
# 45    SMC1   siNipbl   S7  L002_R1_001.fastq.gz  NaN
# 46    SMC1   siNipbl   S7  L003_R1_001.fastq.gz  NaN
# 47    SMC1   siNipbl   S7  L004_R1_001.fastq.gz  NaN
#
#                                       File Genome Norm  Input  \
# 0        input-SiC_S9_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 1        input-SiC_S9_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 2        input-SiC_S9_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 3        input-SiC_S9_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 4   input-SiNipbl_S10_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 5   input-SiNipbl_S10_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 6   input-SiNipbl_S10_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 7   input-SiNipbl_S10_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 8        Sic-NiPBL_S4_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 9        Sic-NiPBL_S4_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 10       Sic-NiPBL_S4_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 11       Sic-NiPBL_S4_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 12         Sic-SA1_S1_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 13         Sic-SA1_S1_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 14         Sic-SA1_S1_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 15         Sic-SA1_S1_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 16    Sic-SA2-new_S11_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 17    Sic-SA2-new_S11_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 18    Sic-SA2-new_S11_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 19    Sic-SA2-new_S11_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 20         Sic-SA2_S2_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 21         Sic-SA2_S2_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 22         Sic-SA2_S2_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 23         Sic-SA2_S2_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 24   Sic-SMC1-new_S12_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 25   Sic-SMC1-new_S12_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 26   Sic-SMC1-new_S12_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 27   Sic-SMC1-new_S12_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 28        Sic-SMC1_S3_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 29        Sic-SMC1_S3_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 30        Sic-SMC1_S3_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 31        Sic-SMC1_S3_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 32   siNipbl-NiPBL_S8_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 33   siNipbl-NiPBL_S8_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 34   siNipbl-NiPBL_S8_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 35   siNipbl-NiPBL_S8_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 36     siNipbl-SA1_S5_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 37     siNipbl-SA1_S5_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 38     siNipbl-SA1_S5_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 39     siNipbl-SA1_S5_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 40     siNipbl-SA2_S6_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 41     siNipbl-SA2_S6_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 42     siNipbl-SA2_S6_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 43     siNipbl-SA2_S6_L004_R1_001.fastq.gz   hg19  mm9    NaN
# 44    siNipbl-SMC1_S7_L001_R1_001.fastq.gz   hg19  mm9    NaN
# 45    siNipbl-SMC1_S7_L002_R1_001.fastq.gz   hg19  mm9    NaN
# 46    siNipbl-SMC1_S7_L003_R1_001.fastq.gz   hg19  mm9    NaN
# 47    siNipbl-SMC1_S7_L004_R1_001.fastq.gz   hg19  mm9    NaN
#
#               Samples
# 0        input_siC_S9
# 1        input_siC_S9
# 2        input_siC_S9
# 3        input_siC_S9
# 4   input_siNipbl_S10
# 5   input_siNipbl_S10
# 6   input_siNipbl_S10
# 7   input_siNipbl_S10
# 8        NiPBL_siC_S4
# 9        NiPBL_siC_S4
# 10       NiPBL_siC_S4
# 11       NiPBL_siC_S4
# 12         SA1_siC_S1
# 13         SA1_siC_S1
# 14         SA1_siC_S1
# 15         SA1_siC_S1
# 16        SA2_siC_S11
# 17        SA2_siC_S11
# 18        SA2_siC_S11
# 19        SA2_siC_S11
# 20         SA2_siC_S2
# 21         SA2_siC_S2
# 22         SA2_siC_S2
# 23         SA2_siC_S2
# 24       SMC1_siC_S12
# 25       SMC1_siC_S12
# 26       SMC1_siC_S12
# 27       SMC1_siC_S12
# 28        SMC1_siC_S3
# 29        SMC1_siC_S3
# 30        SMC1_siC_S3
# 31        SMC1_siC_S3
# 32   NiPBL_siNipbl_S8
# 33   NiPBL_siNipbl_S8
# 34   NiPBL_siNipbl_S8
# 35   NiPBL_siNipbl_S8
# 36     SA1_siNipbl_S5
# 37     SA1_siNipbl_S5
# 38     SA1_siNipbl_S5
# 39     SA1_siNipbl_S5
# 40     SA2_siNipbl_S6
# 41     SA2_siNipbl_S6
# 42     SA2_siNipbl_S6
# 43     SA2_siNipbl_S6
# 44    SMC1_siNipbl_S7
# 45    SMC1_siNipbl_S7
# 46    SMC1_siNipbl_S7
# 47    SMC1_siNipbl_S7

# %%
data["Input"] = [ data.Samples[(data.Protein=="input") & (data.Condition==Cond)].values[0] \
                 if Prot != "input" \
                 else "" \
                 for Prot,Cond in zip(data.Protein,data.Condition)  ]
data
# Out:
#    Protein Condition  Rep                   Ext  Run  \
# 0    input       siC   S9  L001_R1_001.fastq.gz  NaN
# 1    input       siC   S9  L002_R1_001.fastq.gz  NaN
# 2    input       siC   S9  L003_R1_001.fastq.gz  NaN
# 3    input       siC   S9  L004_R1_001.fastq.gz  NaN
# 4    input   siNipbl  S10  L001_R1_001.fastq.gz  NaN
# 5    input   siNipbl  S10  L002_R1_001.fastq.gz  NaN
# 6    input   siNipbl  S10  L003_R1_001.fastq.gz  NaN
# 7    input   siNipbl  S10  L004_R1_001.fastq.gz  NaN
# 8    NiPBL       siC   S4  L001_R1_001.fastq.gz  NaN
# 9    NiPBL       siC   S4  L002_R1_001.fastq.gz  NaN
# 10   NiPBL       siC   S4  L003_R1_001.fastq.gz  NaN
# 11   NiPBL       siC   S4  L004_R1_001.fastq.gz  NaN
# 12     SA1       siC   S1  L001_R1_001.fastq.gz  NaN
# 13     SA1       siC   S1  L002_R1_001.fastq.gz  NaN
# 14     SA1       siC   S1  L003_R1_001.fastq.gz  NaN
# 15     SA1       siC   S1  L004_R1_001.fastq.gz  NaN
# 16     SA2       siC  S11  L001_R1_001.fastq.gz  NaN
# 17     SA2       siC  S11  L002_R1_001.fastq.gz  NaN
# 18     SA2       siC  S11  L003_R1_001.fastq.gz  NaN
# 19     SA2       siC  S11  L004_R1_001.fastq.gz  NaN
# 20     SA2       siC   S2  L001_R1_001.fastq.gz  NaN
# 21     SA2       siC   S2  L002_R1_001.fastq.gz  NaN
# 22     SA2       siC   S2  L003_R1_001.fastq.gz  NaN
# 23     SA2       siC   S2  L004_R1_001.fastq.gz  NaN
# 24    SMC1       siC  S12  L001_R1_001.fastq.gz  NaN
# 25    SMC1       siC  S12  L002_R1_001.fastq.gz  NaN
# 26    SMC1       siC  S12  L003_R1_001.fastq.gz  NaN
# 27    SMC1       siC  S12  L004_R1_001.fastq.gz  NaN
# 28    SMC1       siC   S3  L001_R1_001.fastq.gz  NaN
# 29    SMC1       siC   S3  L002_R1_001.fastq.gz  NaN
# 30    SMC1       siC   S3  L003_R1_001.fastq.gz  NaN
# 31    SMC1       siC   S3  L004_R1_001.fastq.gz  NaN
# 32   NiPBL   siNipbl   S8  L001_R1_001.fastq.gz  NaN
# 33   NiPBL   siNipbl   S8  L002_R1_001.fastq.gz  NaN
# 34   NiPBL   siNipbl   S8  L003_R1_001.fastq.gz  NaN
# 35   NiPBL   siNipbl   S8  L004_R1_001.fastq.gz  NaN
# 36     SA1   siNipbl   S5  L001_R1_001.fastq.gz  NaN
# 37     SA1   siNipbl   S5  L002_R1_001.fastq.gz  NaN
# 38     SA1   siNipbl   S5  L003_R1_001.fastq.gz  NaN
# 39     SA1   siNipbl   S5  L004_R1_001.fastq.gz  NaN
# 40     SA2   siNipbl   S6  L001_R1_001.fastq.gz  NaN
# 41     SA2   siNipbl   S6  L002_R1_001.fastq.gz  NaN
# 42     SA2   siNipbl   S6  L003_R1_001.fastq.gz  NaN
# 43     SA2   siNipbl   S6  L004_R1_001.fastq.gz  NaN
# 44    SMC1   siNipbl   S7  L001_R1_001.fastq.gz  NaN
# 45    SMC1   siNipbl   S7  L002_R1_001.fastq.gz  NaN
# 46    SMC1   siNipbl   S7  L003_R1_001.fastq.gz  NaN
# 47    SMC1   siNipbl   S7  L004_R1_001.fastq.gz  NaN
#
#                                       File Genome Norm              Input  \
# 0        input-SiC_S9_L001_R1_001.fastq.gz   hg19  mm9
# 1        input-SiC_S9_L002_R1_001.fastq.gz   hg19  mm9
# 2        input-SiC_S9_L003_R1_001.fastq.gz   hg19  mm9
# 3        input-SiC_S9_L004_R1_001.fastq.gz   hg19  mm9
# 4   input-SiNipbl_S10_L001_R1_001.fastq.gz   hg19  mm9
# 5   input-SiNipbl_S10_L002_R1_001.fastq.gz   hg19  mm9
# 6   input-SiNipbl_S10_L003_R1_001.fastq.gz   hg19  mm9
# 7   input-SiNipbl_S10_L004_R1_001.fastq.gz   hg19  mm9
# 8        Sic-NiPBL_S4_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 9        Sic-NiPBL_S4_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 10       Sic-NiPBL_S4_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 11       Sic-NiPBL_S4_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 12         Sic-SA1_S1_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 13         Sic-SA1_S1_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 14         Sic-SA1_S1_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 15         Sic-SA1_S1_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 16    Sic-SA2-new_S11_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 17    Sic-SA2-new_S11_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 18    Sic-SA2-new_S11_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 19    Sic-SA2-new_S11_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 20         Sic-SA2_S2_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 21         Sic-SA2_S2_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 22         Sic-SA2_S2_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 23         Sic-SA2_S2_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 24   Sic-SMC1-new_S12_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 25   Sic-SMC1-new_S12_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 26   Sic-SMC1-new_S12_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 27   Sic-SMC1-new_S12_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 28        Sic-SMC1_S3_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 29        Sic-SMC1_S3_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 30        Sic-SMC1_S3_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 31        Sic-SMC1_S3_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 32   siNipbl-NiPBL_S8_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 33   siNipbl-NiPBL_S8_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 34   siNipbl-NiPBL_S8_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 35   siNipbl-NiPBL_S8_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 36     siNipbl-SA1_S5_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 37     siNipbl-SA1_S5_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 38     siNipbl-SA1_S5_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 39     siNipbl-SA1_S5_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 40     siNipbl-SA2_S6_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 41     siNipbl-SA2_S6_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 42     siNipbl-SA2_S6_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 43     siNipbl-SA2_S6_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 44    siNipbl-SMC1_S7_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 45    siNipbl-SMC1_S7_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 46    siNipbl-SMC1_S7_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 47    siNipbl-SMC1_S7_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
#
#               Samples
# 0        input_siC_S9
# 1        input_siC_S9
# 2        input_siC_S9
# 3        input_siC_S9
# 4   input_siNipbl_S10
# 5   input_siNipbl_S10
# 6   input_siNipbl_S10
# 7   input_siNipbl_S10
# 8        NiPBL_siC_S4
# 9        NiPBL_siC_S4
# 10       NiPBL_siC_S4
# 11       NiPBL_siC_S4
# 12         SA1_siC_S1
# 13         SA1_siC_S1
# 14         SA1_siC_S1
# 15         SA1_siC_S1
# 16        SA2_siC_S11
# 17        SA2_siC_S11
# 18        SA2_siC_S11
# 19        SA2_siC_S11
# 20         SA2_siC_S2
# 21         SA2_siC_S2
# 22         SA2_siC_S2
# 23         SA2_siC_S2
# 24       SMC1_siC_S12
# 25       SMC1_siC_S12
# 26       SMC1_siC_S12
# 27       SMC1_siC_S12
# 28        SMC1_siC_S3
# 29        SMC1_siC_S3
# 30        SMC1_siC_S3
# 31        SMC1_siC_S3
# 32   NiPBL_siNipbl_S8
# 33   NiPBL_siNipbl_S8
# 34   NiPBL_siNipbl_S8
# 35   NiPBL_siNipbl_S8
# 36     SA1_siNipbl_S5
# 37     SA1_siNipbl_S5
# 38     SA1_siNipbl_S5
# 39     SA1_siNipbl_S5
# 40     SA2_siNipbl_S6
# 41     SA2_siNipbl_S6
# 42     SA2_siNipbl_S6
# 43     SA2_siNipbl_S6
# 44    SMC1_siNipbl_S7
# 45    SMC1_siNipbl_S7
# 46    SMC1_siNipbl_S7
# 47    SMC1_siNipbl_S7

# %%
data["PATH_genome"] = [genome_path[i] for i in data.Genome] 
data
# Out:
#    Protein Condition  Rep                   Ext  Run  \
# 0    input       siC   S9  L001_R1_001.fastq.gz  NaN
# 1    input       siC   S9  L002_R1_001.fastq.gz  NaN
# 2    input       siC   S9  L003_R1_001.fastq.gz  NaN
# 3    input       siC   S9  L004_R1_001.fastq.gz  NaN
# 4    input   siNipbl  S10  L001_R1_001.fastq.gz  NaN
# 5    input   siNipbl  S10  L002_R1_001.fastq.gz  NaN
# 6    input   siNipbl  S10  L003_R1_001.fastq.gz  NaN
# 7    input   siNipbl  S10  L004_R1_001.fastq.gz  NaN
# 8    NiPBL       siC   S4  L001_R1_001.fastq.gz  NaN
# 9    NiPBL       siC   S4  L002_R1_001.fastq.gz  NaN
# 10   NiPBL       siC   S4  L003_R1_001.fastq.gz  NaN
# 11   NiPBL       siC   S4  L004_R1_001.fastq.gz  NaN
# 12     SA1       siC   S1  L001_R1_001.fastq.gz  NaN
# 13     SA1       siC   S1  L002_R1_001.fastq.gz  NaN
# 14     SA1       siC   S1  L003_R1_001.fastq.gz  NaN
# 15     SA1       siC   S1  L004_R1_001.fastq.gz  NaN
# 16     SA2       siC  S11  L001_R1_001.fastq.gz  NaN
# 17     SA2       siC  S11  L002_R1_001.fastq.gz  NaN
# 18     SA2       siC  S11  L003_R1_001.fastq.gz  NaN
# 19     SA2       siC  S11  L004_R1_001.fastq.gz  NaN
# 20     SA2       siC   S2  L001_R1_001.fastq.gz  NaN
# 21     SA2       siC   S2  L002_R1_001.fastq.gz  NaN
# 22     SA2       siC   S2  L003_R1_001.fastq.gz  NaN
# 23     SA2       siC   S2  L004_R1_001.fastq.gz  NaN
# 24    SMC1       siC  S12  L001_R1_001.fastq.gz  NaN
# 25    SMC1       siC  S12  L002_R1_001.fastq.gz  NaN
# 26    SMC1       siC  S12  L003_R1_001.fastq.gz  NaN
# 27    SMC1       siC  S12  L004_R1_001.fastq.gz  NaN
# 28    SMC1       siC   S3  L001_R1_001.fastq.gz  NaN
# 29    SMC1       siC   S3  L002_R1_001.fastq.gz  NaN
# 30    SMC1       siC   S3  L003_R1_001.fastq.gz  NaN
# 31    SMC1       siC   S3  L004_R1_001.fastq.gz  NaN
# 32   NiPBL   siNipbl   S8  L001_R1_001.fastq.gz  NaN
# 33   NiPBL   siNipbl   S8  L002_R1_001.fastq.gz  NaN
# 34   NiPBL   siNipbl   S8  L003_R1_001.fastq.gz  NaN
# 35   NiPBL   siNipbl   S8  L004_R1_001.fastq.gz  NaN
# 36     SA1   siNipbl   S5  L001_R1_001.fastq.gz  NaN
# 37     SA1   siNipbl   S5  L002_R1_001.fastq.gz  NaN
# 38     SA1   siNipbl   S5  L003_R1_001.fastq.gz  NaN
# 39     SA1   siNipbl   S5  L004_R1_001.fastq.gz  NaN
# 40     SA2   siNipbl   S6  L001_R1_001.fastq.gz  NaN
# 41     SA2   siNipbl   S6  L002_R1_001.fastq.gz  NaN
# 42     SA2   siNipbl   S6  L003_R1_001.fastq.gz  NaN
# 43     SA2   siNipbl   S6  L004_R1_001.fastq.gz  NaN
# 44    SMC1   siNipbl   S7  L001_R1_001.fastq.gz  NaN
# 45    SMC1   siNipbl   S7  L002_R1_001.fastq.gz  NaN
# 46    SMC1   siNipbl   S7  L003_R1_001.fastq.gz  NaN
# 47    SMC1   siNipbl   S7  L004_R1_001.fastq.gz  NaN
#
#                                       File Genome Norm              Input  \
# 0        input-SiC_S9_L001_R1_001.fastq.gz   hg19  mm9
# 1        input-SiC_S9_L002_R1_001.fastq.gz   hg19  mm9
# 2        input-SiC_S9_L003_R1_001.fastq.gz   hg19  mm9
# 3        input-SiC_S9_L004_R1_001.fastq.gz   hg19  mm9
# 4   input-SiNipbl_S10_L001_R1_001.fastq.gz   hg19  mm9
# 5   input-SiNipbl_S10_L002_R1_001.fastq.gz   hg19  mm9
# 6   input-SiNipbl_S10_L003_R1_001.fastq.gz   hg19  mm9
# 7   input-SiNipbl_S10_L004_R1_001.fastq.gz   hg19  mm9
# 8        Sic-NiPBL_S4_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 9        Sic-NiPBL_S4_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 10       Sic-NiPBL_S4_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 11       Sic-NiPBL_S4_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 12         Sic-SA1_S1_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 13         Sic-SA1_S1_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 14         Sic-SA1_S1_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 15         Sic-SA1_S1_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 16    Sic-SA2-new_S11_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 17    Sic-SA2-new_S11_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 18    Sic-SA2-new_S11_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 19    Sic-SA2-new_S11_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 20         Sic-SA2_S2_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 21         Sic-SA2_S2_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 22         Sic-SA2_S2_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 23         Sic-SA2_S2_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 24   Sic-SMC1-new_S12_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 25   Sic-SMC1-new_S12_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 26   Sic-SMC1-new_S12_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 27   Sic-SMC1-new_S12_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 28        Sic-SMC1_S3_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 29        Sic-SMC1_S3_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 30        Sic-SMC1_S3_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 31        Sic-SMC1_S3_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 32   siNipbl-NiPBL_S8_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 33   siNipbl-NiPBL_S8_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 34   siNipbl-NiPBL_S8_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 35   siNipbl-NiPBL_S8_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 36     siNipbl-SA1_S5_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 37     siNipbl-SA1_S5_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 38     siNipbl-SA1_S5_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 39     siNipbl-SA1_S5_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 40     siNipbl-SA2_S6_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 41     siNipbl-SA2_S6_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 42     siNipbl-SA2_S6_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 43     siNipbl-SA2_S6_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 44    siNipbl-SMC1_S7_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 45    siNipbl-SMC1_S7_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 46    siNipbl-SMC1_S7_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 47    siNipbl-SMC1_S7_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
#
#               Samples                                        PATH_genome
# 0        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 1        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 2        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 3        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 4   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 5   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 6   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 7   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 8        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 9        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 10       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 11       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 12         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 13         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 14         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 15         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 16        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 17        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 18        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 19        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 20         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 21         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 22         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 23         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 24       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 25       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 26       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 27       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 28        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 29        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 30        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 31        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 32   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 33   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 34   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 35   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 36     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 37     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 38     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 39     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 40     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 41     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 42     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 43     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 44    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 45    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 46    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 47    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...

# %%
data["Genome_size"] = [genome_size[i] for i in data.Genome]
data[1:12:2].Condition
# Out:
# 1         siC
# 3         siC
# 5     siNipbl
# 7     siNipbl
# 9         siC
# 11        siC
# Name: Condition, dtype: object

# %%
data["PATH_genome_cal"] = [genome_path[i] for i in data.Norm]
data
# Out:
#    Protein Condition  Rep                   Ext  Run  \
# 0    input       siC   S9  L001_R1_001.fastq.gz  NaN
# 1    input       siC   S9  L002_R1_001.fastq.gz  NaN
# 2    input       siC   S9  L003_R1_001.fastq.gz  NaN
# 3    input       siC   S9  L004_R1_001.fastq.gz  NaN
# 4    input   siNipbl  S10  L001_R1_001.fastq.gz  NaN
# 5    input   siNipbl  S10  L002_R1_001.fastq.gz  NaN
# 6    input   siNipbl  S10  L003_R1_001.fastq.gz  NaN
# 7    input   siNipbl  S10  L004_R1_001.fastq.gz  NaN
# 8    NiPBL       siC   S4  L001_R1_001.fastq.gz  NaN
# 9    NiPBL       siC   S4  L002_R1_001.fastq.gz  NaN
# 10   NiPBL       siC   S4  L003_R1_001.fastq.gz  NaN
# 11   NiPBL       siC   S4  L004_R1_001.fastq.gz  NaN
# 12     SA1       siC   S1  L001_R1_001.fastq.gz  NaN
# 13     SA1       siC   S1  L002_R1_001.fastq.gz  NaN
# 14     SA1       siC   S1  L003_R1_001.fastq.gz  NaN
# 15     SA1       siC   S1  L004_R1_001.fastq.gz  NaN
# 16     SA2       siC  S11  L001_R1_001.fastq.gz  NaN
# 17     SA2       siC  S11  L002_R1_001.fastq.gz  NaN
# 18     SA2       siC  S11  L003_R1_001.fastq.gz  NaN
# 19     SA2       siC  S11  L004_R1_001.fastq.gz  NaN
# 20     SA2       siC   S2  L001_R1_001.fastq.gz  NaN
# 21     SA2       siC   S2  L002_R1_001.fastq.gz  NaN
# 22     SA2       siC   S2  L003_R1_001.fastq.gz  NaN
# 23     SA2       siC   S2  L004_R1_001.fastq.gz  NaN
# 24    SMC1       siC  S12  L001_R1_001.fastq.gz  NaN
# 25    SMC1       siC  S12  L002_R1_001.fastq.gz  NaN
# 26    SMC1       siC  S12  L003_R1_001.fastq.gz  NaN
# 27    SMC1       siC  S12  L004_R1_001.fastq.gz  NaN
# 28    SMC1       siC   S3  L001_R1_001.fastq.gz  NaN
# 29    SMC1       siC   S3  L002_R1_001.fastq.gz  NaN
# 30    SMC1       siC   S3  L003_R1_001.fastq.gz  NaN
# 31    SMC1       siC   S3  L004_R1_001.fastq.gz  NaN
# 32   NiPBL   siNipbl   S8  L001_R1_001.fastq.gz  NaN
# 33   NiPBL   siNipbl   S8  L002_R1_001.fastq.gz  NaN
# 34   NiPBL   siNipbl   S8  L003_R1_001.fastq.gz  NaN
# 35   NiPBL   siNipbl   S8  L004_R1_001.fastq.gz  NaN
# 36     SA1   siNipbl   S5  L001_R1_001.fastq.gz  NaN
# 37     SA1   siNipbl   S5  L002_R1_001.fastq.gz  NaN
# 38     SA1   siNipbl   S5  L003_R1_001.fastq.gz  NaN
# 39     SA1   siNipbl   S5  L004_R1_001.fastq.gz  NaN
# 40     SA2   siNipbl   S6  L001_R1_001.fastq.gz  NaN
# 41     SA2   siNipbl   S6  L002_R1_001.fastq.gz  NaN
# 42     SA2   siNipbl   S6  L003_R1_001.fastq.gz  NaN
# 43     SA2   siNipbl   S6  L004_R1_001.fastq.gz  NaN
# 44    SMC1   siNipbl   S7  L001_R1_001.fastq.gz  NaN
# 45    SMC1   siNipbl   S7  L002_R1_001.fastq.gz  NaN
# 46    SMC1   siNipbl   S7  L003_R1_001.fastq.gz  NaN
# 47    SMC1   siNipbl   S7  L004_R1_001.fastq.gz  NaN
#
#                                       File Genome Norm              Input  \
# 0        input-SiC_S9_L001_R1_001.fastq.gz   hg19  mm9
# 1        input-SiC_S9_L002_R1_001.fastq.gz   hg19  mm9
# 2        input-SiC_S9_L003_R1_001.fastq.gz   hg19  mm9
# 3        input-SiC_S9_L004_R1_001.fastq.gz   hg19  mm9
# 4   input-SiNipbl_S10_L001_R1_001.fastq.gz   hg19  mm9
# 5   input-SiNipbl_S10_L002_R1_001.fastq.gz   hg19  mm9
# 6   input-SiNipbl_S10_L003_R1_001.fastq.gz   hg19  mm9
# 7   input-SiNipbl_S10_L004_R1_001.fastq.gz   hg19  mm9
# 8        Sic-NiPBL_S4_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 9        Sic-NiPBL_S4_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 10       Sic-NiPBL_S4_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 11       Sic-NiPBL_S4_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 12         Sic-SA1_S1_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 13         Sic-SA1_S1_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 14         Sic-SA1_S1_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 15         Sic-SA1_S1_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 16    Sic-SA2-new_S11_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 17    Sic-SA2-new_S11_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 18    Sic-SA2-new_S11_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 19    Sic-SA2-new_S11_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 20         Sic-SA2_S2_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 21         Sic-SA2_S2_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 22         Sic-SA2_S2_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 23         Sic-SA2_S2_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 24   Sic-SMC1-new_S12_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 25   Sic-SMC1-new_S12_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 26   Sic-SMC1-new_S12_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 27   Sic-SMC1-new_S12_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 28        Sic-SMC1_S3_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 29        Sic-SMC1_S3_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 30        Sic-SMC1_S3_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 31        Sic-SMC1_S3_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 32   siNipbl-NiPBL_S8_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 33   siNipbl-NiPBL_S8_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 34   siNipbl-NiPBL_S8_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 35   siNipbl-NiPBL_S8_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 36     siNipbl-SA1_S5_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 37     siNipbl-SA1_S5_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 38     siNipbl-SA1_S5_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 39     siNipbl-SA1_S5_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 40     siNipbl-SA2_S6_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 41     siNipbl-SA2_S6_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 42     siNipbl-SA2_S6_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 43     siNipbl-SA2_S6_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 44    siNipbl-SMC1_S7_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 45    siNipbl-SMC1_S7_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 46    siNipbl-SMC1_S7_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 47    siNipbl-SMC1_S7_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
#
#               Samples                                        PATH_genome  \
# 0        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 1        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 2        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 3        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 4   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 5   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 6   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 7   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 8        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 9        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 10       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 11       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 12         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 13         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 14         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 15         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 16        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 17        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 18        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 19        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 20         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 21         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 22         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 23         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 24       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 25       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 26       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 27       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 28        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 29        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 30        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 31        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 32   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 33   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 34   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 35   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 36     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 37     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 38     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 39     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 40     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 41     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 42     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 43     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 44    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 45    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 46    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 47    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
#
#     Genome_size                                    PATH_genome_cal
# 0    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 1    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 2    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 3    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 4    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 5    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 6    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 7    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 8    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 9    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 10   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 11   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 12   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 13   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 14   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 15   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 16   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 17   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 18   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 19   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 20   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 21   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 22   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 23   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 24   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 25   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 26   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 27   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 28   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 29   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 30   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 31   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 32   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 33   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 34   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 35   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 36   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 37   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 38   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 39   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 40   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 41   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 42   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 43   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 44   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 45   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 46   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 47   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...

# %%
data["PATH_refSeq_genes"] = [refSeq_genes_path[i] for i in data.Genome]
data
# Out:
#    Protein Condition  Rep                   Ext  Run  \
# 0    input       siC   S9  L001_R1_001.fastq.gz  NaN
# 1    input       siC   S9  L002_R1_001.fastq.gz  NaN
# 2    input       siC   S9  L003_R1_001.fastq.gz  NaN
# 3    input       siC   S9  L004_R1_001.fastq.gz  NaN
# 4    input   siNipbl  S10  L001_R1_001.fastq.gz  NaN
# 5    input   siNipbl  S10  L002_R1_001.fastq.gz  NaN
# 6    input   siNipbl  S10  L003_R1_001.fastq.gz  NaN
# 7    input   siNipbl  S10  L004_R1_001.fastq.gz  NaN
# 8    NiPBL       siC   S4  L001_R1_001.fastq.gz  NaN
# 9    NiPBL       siC   S4  L002_R1_001.fastq.gz  NaN
# 10   NiPBL       siC   S4  L003_R1_001.fastq.gz  NaN
# 11   NiPBL       siC   S4  L004_R1_001.fastq.gz  NaN
# 12     SA1       siC   S1  L001_R1_001.fastq.gz  NaN
# 13     SA1       siC   S1  L002_R1_001.fastq.gz  NaN
# 14     SA1       siC   S1  L003_R1_001.fastq.gz  NaN
# 15     SA1       siC   S1  L004_R1_001.fastq.gz  NaN
# 16     SA2       siC  S11  L001_R1_001.fastq.gz  NaN
# 17     SA2       siC  S11  L002_R1_001.fastq.gz  NaN
# 18     SA2       siC  S11  L003_R1_001.fastq.gz  NaN
# 19     SA2       siC  S11  L004_R1_001.fastq.gz  NaN
# 20     SA2       siC   S2  L001_R1_001.fastq.gz  NaN
# 21     SA2       siC   S2  L002_R1_001.fastq.gz  NaN
# 22     SA2       siC   S2  L003_R1_001.fastq.gz  NaN
# 23     SA2       siC   S2  L004_R1_001.fastq.gz  NaN
# 24    SMC1       siC  S12  L001_R1_001.fastq.gz  NaN
# 25    SMC1       siC  S12  L002_R1_001.fastq.gz  NaN
# 26    SMC1       siC  S12  L003_R1_001.fastq.gz  NaN
# 27    SMC1       siC  S12  L004_R1_001.fastq.gz  NaN
# 28    SMC1       siC   S3  L001_R1_001.fastq.gz  NaN
# 29    SMC1       siC   S3  L002_R1_001.fastq.gz  NaN
# 30    SMC1       siC   S3  L003_R1_001.fastq.gz  NaN
# 31    SMC1       siC   S3  L004_R1_001.fastq.gz  NaN
# 32   NiPBL   siNipbl   S8  L001_R1_001.fastq.gz  NaN
# 33   NiPBL   siNipbl   S8  L002_R1_001.fastq.gz  NaN
# 34   NiPBL   siNipbl   S8  L003_R1_001.fastq.gz  NaN
# 35   NiPBL   siNipbl   S8  L004_R1_001.fastq.gz  NaN
# 36     SA1   siNipbl   S5  L001_R1_001.fastq.gz  NaN
# 37     SA1   siNipbl   S5  L002_R1_001.fastq.gz  NaN
# 38     SA1   siNipbl   S5  L003_R1_001.fastq.gz  NaN
# 39     SA1   siNipbl   S5  L004_R1_001.fastq.gz  NaN
# 40     SA2   siNipbl   S6  L001_R1_001.fastq.gz  NaN
# 41     SA2   siNipbl   S6  L002_R1_001.fastq.gz  NaN
# 42     SA2   siNipbl   S6  L003_R1_001.fastq.gz  NaN
# 43     SA2   siNipbl   S6  L004_R1_001.fastq.gz  NaN
# 44    SMC1   siNipbl   S7  L001_R1_001.fastq.gz  NaN
# 45    SMC1   siNipbl   S7  L002_R1_001.fastq.gz  NaN
# 46    SMC1   siNipbl   S7  L003_R1_001.fastq.gz  NaN
# 47    SMC1   siNipbl   S7  L004_R1_001.fastq.gz  NaN
#
#                                       File Genome Norm              Input  \
# 0        input-SiC_S9_L001_R1_001.fastq.gz   hg19  mm9
# 1        input-SiC_S9_L002_R1_001.fastq.gz   hg19  mm9
# 2        input-SiC_S9_L003_R1_001.fastq.gz   hg19  mm9
# 3        input-SiC_S9_L004_R1_001.fastq.gz   hg19  mm9
# 4   input-SiNipbl_S10_L001_R1_001.fastq.gz   hg19  mm9
# 5   input-SiNipbl_S10_L002_R1_001.fastq.gz   hg19  mm9
# 6   input-SiNipbl_S10_L003_R1_001.fastq.gz   hg19  mm9
# 7   input-SiNipbl_S10_L004_R1_001.fastq.gz   hg19  mm9
# 8        Sic-NiPBL_S4_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 9        Sic-NiPBL_S4_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 10       Sic-NiPBL_S4_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 11       Sic-NiPBL_S4_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 12         Sic-SA1_S1_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 13         Sic-SA1_S1_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 14         Sic-SA1_S1_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 15         Sic-SA1_S1_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 16    Sic-SA2-new_S11_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 17    Sic-SA2-new_S11_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 18    Sic-SA2-new_S11_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 19    Sic-SA2-new_S11_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 20         Sic-SA2_S2_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 21         Sic-SA2_S2_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 22         Sic-SA2_S2_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 23         Sic-SA2_S2_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 24   Sic-SMC1-new_S12_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 25   Sic-SMC1-new_S12_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 26   Sic-SMC1-new_S12_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 27   Sic-SMC1-new_S12_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 28        Sic-SMC1_S3_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 29        Sic-SMC1_S3_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 30        Sic-SMC1_S3_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 31        Sic-SMC1_S3_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 32   siNipbl-NiPBL_S8_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 33   siNipbl-NiPBL_S8_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 34   siNipbl-NiPBL_S8_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 35   siNipbl-NiPBL_S8_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 36     siNipbl-SA1_S5_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 37     siNipbl-SA1_S5_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 38     siNipbl-SA1_S5_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 39     siNipbl-SA1_S5_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 40     siNipbl-SA2_S6_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 41     siNipbl-SA2_S6_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 42     siNipbl-SA2_S6_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 43     siNipbl-SA2_S6_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 44    siNipbl-SMC1_S7_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 45    siNipbl-SMC1_S7_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 46    siNipbl-SMC1_S7_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 47    siNipbl-SMC1_S7_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
#
#               Samples                                        PATH_genome  \
# 0        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 1        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 2        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 3        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 4   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 5   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 6   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 7   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 8        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 9        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 10       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 11       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 12         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 13         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 14         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 15         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 16        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 17        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 18        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 19        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 20         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 21         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 22         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 23         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 24       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 25       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 26       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 27       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 28        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 29        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 30        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 31        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 32   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 33   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 34   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 35   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 36     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 37     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 38     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 39     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 40     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 41     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 42     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 43     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 44    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 45    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 46    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 47    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
#
#     Genome_size                                    PATH_genome_cal  \
# 0    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 1    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 2    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 3    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 4    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 5    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 6    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 7    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 8    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 9    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 10   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 11   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 12   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 13   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 14   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 15   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 16   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 17   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 18   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 19   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 20   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 21   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 22   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 23   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 24   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 25   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 26   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 27   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 28   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 29   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 30   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 31   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 32   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 33   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 34   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 35   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 36   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 37   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 38   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 39   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 40   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 41   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 42   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 43   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 44   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 45   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 46   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 47   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
#
#                                     PATH_refSeq_genes
# 0   /storage/scratch01/users/aquevedo/genomes/huma...
# 1   /storage/scratch01/users/aquevedo/genomes/huma...
# 2   /storage/scratch01/users/aquevedo/genomes/huma...
# 3   /storage/scratch01/users/aquevedo/genomes/huma...
# 4   /storage/scratch01/users/aquevedo/genomes/huma...
# 5   /storage/scratch01/users/aquevedo/genomes/huma...
# 6   /storage/scratch01/users/aquevedo/genomes/huma...
# 7   /storage/scratch01/users/aquevedo/genomes/huma...
# 8   /storage/scratch01/users/aquevedo/genomes/huma...
# 9   /storage/scratch01/users/aquevedo/genomes/huma...
# 10  /storage/scratch01/users/aquevedo/genomes/huma...
# 11  /storage/scratch01/users/aquevedo/genomes/huma...
# 12  /storage/scratch01/users/aquevedo/genomes/huma...
# 13  /storage/scratch01/users/aquevedo/genomes/huma...
# 14  /storage/scratch01/users/aquevedo/genomes/huma...
# 15  /storage/scratch01/users/aquevedo/genomes/huma...
# 16  /storage/scratch01/users/aquevedo/genomes/huma...
# 17  /storage/scratch01/users/aquevedo/genomes/huma...
# 18  /storage/scratch01/users/aquevedo/genomes/huma...
# 19  /storage/scratch01/users/aquevedo/genomes/huma...
# 20  /storage/scratch01/users/aquevedo/genomes/huma...
# 21  /storage/scratch01/users/aquevedo/genomes/huma...
# 22  /storage/scratch01/users/aquevedo/genomes/huma...
# 23  /storage/scratch01/users/aquevedo/genomes/huma...
# 24  /storage/scratch01/users/aquevedo/genomes/huma...
# 25  /storage/scratch01/users/aquevedo/genomes/huma...
# 26  /storage/scratch01/users/aquevedo/genomes/huma...
# 27  /storage/scratch01/users/aquevedo/genomes/huma...
# 28  /storage/scratch01/users/aquevedo/genomes/huma...
# 29  /storage/scratch01/users/aquevedo/genomes/huma...
# 30  /storage/scratch01/users/aquevedo/genomes/huma...
# 31  /storage/scratch01/users/aquevedo/genomes/huma...
# 32  /storage/scratch01/users/aquevedo/genomes/huma...
# 33  /storage/scratch01/users/aquevedo/genomes/huma...
# 34  /storage/scratch01/users/aquevedo/genomes/huma...
# 35  /storage/scratch01/users/aquevedo/genomes/huma...
# 36  /storage/scratch01/users/aquevedo/genomes/huma...
# 37  /storage/scratch01/users/aquevedo/genomes/huma...
# 38  /storage/scratch01/users/aquevedo/genomes/huma...
# 39  /storage/scratch01/users/aquevedo/genomes/huma...
# 40  /storage/scratch01/users/aquevedo/genomes/huma...
# 41  /storage/scratch01/users/aquevedo/genomes/huma...
# 42  /storage/scratch01/users/aquevedo/genomes/huma...
# 43  /storage/scratch01/users/aquevedo/genomes/huma...
# 44  /storage/scratch01/users/aquevedo/genomes/huma...
# 45  /storage/scratch01/users/aquevedo/genomes/huma...
# 46  /storage/scratch01/users/aquevedo/genomes/huma...
# 47  /storage/scratch01/users/aquevedo/genomes/huma...

# %%
## Remove .fastq.gz to use basename with expand() in rule "all"
data["fqBasename"] = [f.replace(".fastq.gz","") for f in data["File"]]
data
# Out:
#    Protein Condition  Rep                   Ext  Run  \
# 0    input       siC   S9  L001_R1_001.fastq.gz  NaN
# 1    input       siC   S9  L002_R1_001.fastq.gz  NaN
# 2    input       siC   S9  L003_R1_001.fastq.gz  NaN
# 3    input       siC   S9  L004_R1_001.fastq.gz  NaN
# 4    input   siNipbl  S10  L001_R1_001.fastq.gz  NaN
# 5    input   siNipbl  S10  L002_R1_001.fastq.gz  NaN
# 6    input   siNipbl  S10  L003_R1_001.fastq.gz  NaN
# 7    input   siNipbl  S10  L004_R1_001.fastq.gz  NaN
# 8    NiPBL       siC   S4  L001_R1_001.fastq.gz  NaN
# 9    NiPBL       siC   S4  L002_R1_001.fastq.gz  NaN
# 10   NiPBL       siC   S4  L003_R1_001.fastq.gz  NaN
# 11   NiPBL       siC   S4  L004_R1_001.fastq.gz  NaN
# 12     SA1       siC   S1  L001_R1_001.fastq.gz  NaN
# 13     SA1       siC   S1  L002_R1_001.fastq.gz  NaN
# 14     SA1       siC   S1  L003_R1_001.fastq.gz  NaN
# 15     SA1       siC   S1  L004_R1_001.fastq.gz  NaN
# 16     SA2       siC  S11  L001_R1_001.fastq.gz  NaN
# 17     SA2       siC  S11  L002_R1_001.fastq.gz  NaN
# 18     SA2       siC  S11  L003_R1_001.fastq.gz  NaN
# 19     SA2       siC  S11  L004_R1_001.fastq.gz  NaN
# 20     SA2       siC   S2  L001_R1_001.fastq.gz  NaN
# 21     SA2       siC   S2  L002_R1_001.fastq.gz  NaN
# 22     SA2       siC   S2  L003_R1_001.fastq.gz  NaN
# 23     SA2       siC   S2  L004_R1_001.fastq.gz  NaN
# 24    SMC1       siC  S12  L001_R1_001.fastq.gz  NaN
# 25    SMC1       siC  S12  L002_R1_001.fastq.gz  NaN
# 26    SMC1       siC  S12  L003_R1_001.fastq.gz  NaN
# 27    SMC1       siC  S12  L004_R1_001.fastq.gz  NaN
# 28    SMC1       siC   S3  L001_R1_001.fastq.gz  NaN
# 29    SMC1       siC   S3  L002_R1_001.fastq.gz  NaN
# 30    SMC1       siC   S3  L003_R1_001.fastq.gz  NaN
# 31    SMC1       siC   S3  L004_R1_001.fastq.gz  NaN
# 32   NiPBL   siNipbl   S8  L001_R1_001.fastq.gz  NaN
# 33   NiPBL   siNipbl   S8  L002_R1_001.fastq.gz  NaN
# 34   NiPBL   siNipbl   S8  L003_R1_001.fastq.gz  NaN
# 35   NiPBL   siNipbl   S8  L004_R1_001.fastq.gz  NaN
# 36     SA1   siNipbl   S5  L001_R1_001.fastq.gz  NaN
# 37     SA1   siNipbl   S5  L002_R1_001.fastq.gz  NaN
# 38     SA1   siNipbl   S5  L003_R1_001.fastq.gz  NaN
# 39     SA1   siNipbl   S5  L004_R1_001.fastq.gz  NaN
# 40     SA2   siNipbl   S6  L001_R1_001.fastq.gz  NaN
# 41     SA2   siNipbl   S6  L002_R1_001.fastq.gz  NaN
# 42     SA2   siNipbl   S6  L003_R1_001.fastq.gz  NaN
# 43     SA2   siNipbl   S6  L004_R1_001.fastq.gz  NaN
# 44    SMC1   siNipbl   S7  L001_R1_001.fastq.gz  NaN
# 45    SMC1   siNipbl   S7  L002_R1_001.fastq.gz  NaN
# 46    SMC1   siNipbl   S7  L003_R1_001.fastq.gz  NaN
# 47    SMC1   siNipbl   S7  L004_R1_001.fastq.gz  NaN
#
#                                       File Genome Norm              Input  \
# 0        input-SiC_S9_L001_R1_001.fastq.gz   hg19  mm9
# 1        input-SiC_S9_L002_R1_001.fastq.gz   hg19  mm9
# 2        input-SiC_S9_L003_R1_001.fastq.gz   hg19  mm9
# 3        input-SiC_S9_L004_R1_001.fastq.gz   hg19  mm9
# 4   input-SiNipbl_S10_L001_R1_001.fastq.gz   hg19  mm9
# 5   input-SiNipbl_S10_L002_R1_001.fastq.gz   hg19  mm9
# 6   input-SiNipbl_S10_L003_R1_001.fastq.gz   hg19  mm9
# 7   input-SiNipbl_S10_L004_R1_001.fastq.gz   hg19  mm9
# 8        Sic-NiPBL_S4_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 9        Sic-NiPBL_S4_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 10       Sic-NiPBL_S4_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 11       Sic-NiPBL_S4_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 12         Sic-SA1_S1_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 13         Sic-SA1_S1_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 14         Sic-SA1_S1_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 15         Sic-SA1_S1_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 16    Sic-SA2-new_S11_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 17    Sic-SA2-new_S11_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 18    Sic-SA2-new_S11_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 19    Sic-SA2-new_S11_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 20         Sic-SA2_S2_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 21         Sic-SA2_S2_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 22         Sic-SA2_S2_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 23         Sic-SA2_S2_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 24   Sic-SMC1-new_S12_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 25   Sic-SMC1-new_S12_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 26   Sic-SMC1-new_S12_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 27   Sic-SMC1-new_S12_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 28        Sic-SMC1_S3_L001_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 29        Sic-SMC1_S3_L002_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 30        Sic-SMC1_S3_L003_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 31        Sic-SMC1_S3_L004_R1_001.fastq.gz   hg19  mm9       input_siC_S9
# 32   siNipbl-NiPBL_S8_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 33   siNipbl-NiPBL_S8_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 34   siNipbl-NiPBL_S8_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 35   siNipbl-NiPBL_S8_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 36     siNipbl-SA1_S5_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 37     siNipbl-SA1_S5_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 38     siNipbl-SA1_S5_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 39     siNipbl-SA1_S5_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 40     siNipbl-SA2_S6_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 41     siNipbl-SA2_S6_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 42     siNipbl-SA2_S6_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 43     siNipbl-SA2_S6_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 44    siNipbl-SMC1_S7_L001_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 45    siNipbl-SMC1_S7_L002_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 46    siNipbl-SMC1_S7_L003_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
# 47    siNipbl-SMC1_S7_L004_R1_001.fastq.gz   hg19  mm9  input_siNipbl_S10
#
#               Samples                                        PATH_genome  \
# 0        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 1        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 2        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 3        input_siC_S9  /storage/scratch01/users/dgimenezl/genomes/hum...
# 4   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 5   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 6   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 7   input_siNipbl_S10  /storage/scratch01/users/dgimenezl/genomes/hum...
# 8        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 9        NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 10       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 11       NiPBL_siC_S4  /storage/scratch01/users/dgimenezl/genomes/hum...
# 12         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 13         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 14         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 15         SA1_siC_S1  /storage/scratch01/users/dgimenezl/genomes/hum...
# 16        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 17        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 18        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 19        SA2_siC_S11  /storage/scratch01/users/dgimenezl/genomes/hum...
# 20         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 21         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 22         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 23         SA2_siC_S2  /storage/scratch01/users/dgimenezl/genomes/hum...
# 24       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 25       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 26       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 27       SMC1_siC_S12  /storage/scratch01/users/dgimenezl/genomes/hum...
# 28        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 29        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 30        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 31        SMC1_siC_S3  /storage/scratch01/users/dgimenezl/genomes/hum...
# 32   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 33   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 34   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 35   NiPBL_siNipbl_S8  /storage/scratch01/users/dgimenezl/genomes/hum...
# 36     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 37     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 38     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 39     SA1_siNipbl_S5  /storage/scratch01/users/dgimenezl/genomes/hum...
# 40     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 41     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 42     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 43     SA2_siNipbl_S6  /storage/scratch01/users/dgimenezl/genomes/hum...
# 44    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 45    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 46    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
# 47    SMC1_siNipbl_S7  /storage/scratch01/users/dgimenezl/genomes/hum...
#
#     Genome_size                                    PATH_genome_cal  \
# 0    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 1    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 2    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 3    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 4    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 5    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 6    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 7    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 8    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 9    2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 10   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 11   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 12   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 13   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 14   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 15   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 16   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 17   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 18   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 19   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 20   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 21   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 22   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 23   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 24   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 25   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 26   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 27   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 28   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 29   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 30   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 31   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 32   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 33   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 34   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 35   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 36   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 37   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 38   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 39   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 40   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 41   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 42   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 43   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 44   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 45   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 46   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
# 47   2864785220  /storage/scratch01/users/dgimenezl/genomes/mou...
#
#                                     PATH_refSeq_genes  \
# 0   /storage/scratch01/users/aquevedo/genomes/huma...
# 1   /storage/scratch01/users/aquevedo/genomes/huma...
# 2   /storage/scratch01/users/aquevedo/genomes/huma...
# 3   /storage/scratch01/users/aquevedo/genomes/huma...
# 4   /storage/scratch01/users/aquevedo/genomes/huma...
# 5   /storage/scratch01/users/aquevedo/genomes/huma...
# 6   /storage/scratch01/users/aquevedo/genomes/huma...
# 7   /storage/scratch01/users/aquevedo/genomes/huma...
# 8   /storage/scratch01/users/aquevedo/genomes/huma...
# 9   /storage/scratch01/users/aquevedo/genomes/huma...
# 10  /storage/scratch01/users/aquevedo/genomes/huma...
# 11  /storage/scratch01/users/aquevedo/genomes/huma...
# 12  /storage/scratch01/users/aquevedo/genomes/huma...
# 13  /storage/scratch01/users/aquevedo/genomes/huma...
# 14  /storage/scratch01/users/aquevedo/genomes/huma...
# 15  /storage/scratch01/users/aquevedo/genomes/huma...
# 16  /storage/scratch01/users/aquevedo/genomes/huma...
# 17  /storage/scratch01/users/aquevedo/genomes/huma...
# 18  /storage/scratch01/users/aquevedo/genomes/huma...
# 19  /storage/scratch01/users/aquevedo/genomes/huma...
# 20  /storage/scratch01/users/aquevedo/genomes/huma...
# 21  /storage/scratch01/users/aquevedo/genomes/huma...
# 22  /storage/scratch01/users/aquevedo/genomes/huma...
# 23  /storage/scratch01/users/aquevedo/genomes/huma...
# 24  /storage/scratch01/users/aquevedo/genomes/huma...
# 25  /storage/scratch01/users/aquevedo/genomes/huma...
# 26  /storage/scratch01/users/aquevedo/genomes/huma...
# 27  /storage/scratch01/users/aquevedo/genomes/huma...
# 28  /storage/scratch01/users/aquevedo/genomes/huma...
# 29  /storage/scratch01/users/aquevedo/genomes/huma...
# 30  /storage/scratch01/users/aquevedo/genomes/huma...
# 31  /storage/scratch01/users/aquevedo/genomes/huma...
# 32  /storage/scratch01/users/aquevedo/genomes/huma...
# 33  /storage/scratch01/users/aquevedo/genomes/huma...
# 34  /storage/scratch01/users/aquevedo/genomes/huma...
# 35  /storage/scratch01/users/aquevedo/genomes/huma...
# 36  /storage/scratch01/users/aquevedo/genomes/huma...
# 37  /storage/scratch01/users/aquevedo/genomes/huma...
# 38  /storage/scratch01/users/aquevedo/genomes/huma...
# 39  /storage/scratch01/users/aquevedo/genomes/huma...
# 40  /storage/scratch01/users/aquevedo/genomes/huma...
# 41  /storage/scratch01/users/aquevedo/genomes/huma...
# 42  /storage/scratch01/users/aquevedo/genomes/huma...
# 43  /storage/scratch01/users/aquevedo/genomes/huma...
# 44  /storage/scratch01/users/aquevedo/genomes/huma...
# 45  /storage/scratch01/users/aquevedo/genomes/huma...
# 46  /storage/scratch01/users/aquevedo/genomes/huma...
# 47  /storage/scratch01/users/aquevedo/genomes/huma...
#
#                        fqBasename
# 0        input-SiC_S9_L001_R1_001
# 1        input-SiC_S9_L002_R1_001
# 2        input-SiC_S9_L003_R1_001
# 3        input-SiC_S9_L004_R1_001
# 4   input-SiNipbl_S10_L001_R1_001
# 5   input-SiNipbl_S10_L002_R1_001
# 6   input-SiNipbl_S10_L003_R1_001
# 7   input-SiNipbl_S10_L004_R1_001
# 8        Sic-NiPBL_S4_L001_R1_001
# 9        Sic-NiPBL_S4_L002_R1_001
# 10       Sic-NiPBL_S4_L003_R1_001
# 11       Sic-NiPBL_S4_L004_R1_001
# 12         Sic-SA1_S1_L001_R1_001
# 13         Sic-SA1_S1_L002_R1_001
# 14         Sic-SA1_S1_L003_R1_001
# 15         Sic-SA1_S1_L004_R1_001
# 16    Sic-SA2-new_S11_L001_R1_001
# 17    Sic-SA2-new_S11_L002_R1_001
# 18    Sic-SA2-new_S11_L003_R1_001
# 19    Sic-SA2-new_S11_L004_R1_001
# 20         Sic-SA2_S2_L001_R1_001
# 21         Sic-SA2_S2_L002_R1_001
# 22         Sic-SA2_S2_L003_R1_001
# 23         Sic-SA2_S2_L004_R1_001
# 24   Sic-SMC1-new_S12_L001_R1_001
# 25   Sic-SMC1-new_S12_L002_R1_001
# 26   Sic-SMC1-new_S12_L003_R1_001
# 27   Sic-SMC1-new_S12_L004_R1_001
# 28        Sic-SMC1_S3_L001_R1_001
# 29        Sic-SMC1_S3_L002_R1_001
# 30        Sic-SMC1_S3_L003_R1_001
# 31        Sic-SMC1_S3_L004_R1_001
# 32   siNipbl-NiPBL_S8_L001_R1_001
# 33   siNipbl-NiPBL_S8_L002_R1_001
# 34   siNipbl-NiPBL_S8_L003_R1_001
# 35   siNipbl-NiPBL_S8_L004_R1_001
# 36     siNipbl-SA1_S5_L001_R1_001
# 37     siNipbl-SA1_S5_L002_R1_001
# 38     siNipbl-SA1_S5_L003_R1_001
# 39     siNipbl-SA1_S5_L004_R1_001
# 40     siNipbl-SA2_S6_L001_R1_001
# 41     siNipbl-SA2_S6_L002_R1_001
# 42     siNipbl-SA2_S6_L003_R1_001
# 43     siNipbl-SA2_S6_L004_R1_001
# 44    siNipbl-SMC1_S7_L001_R1_001
# 45    siNipbl-SMC1_S7_L002_R1_001
# 46    siNipbl-SMC1_S7_L003_R1_001
# 47    siNipbl-SMC1_S7_L004_R1_001

# %% [markdown]
# ## Generate Arguments for MergeSamFiles
# Demonstrate how the command string for MergeSamFiles is produced. We take advantage of the `data` table and the auxiliary function `Input_merge_bam`

# %%
def Input_merge_bam(*bams):
    '''
    Generate formated string for -I option for MergeSamFiles
    '''
    input_bams=["-I " + str(b) for b in bams]
    input_bams=" ".join(input_bams)
    return input_bams

# %%
## generate a list with .bam filenames the same way as in the Snakefile
sample=data.Samples[(data.Protein == 'SA2') & (data.Condition == 'siC')].unique()
print("sample: ", sample)
bams=[s +'_final.bam' for s in sample]
print("Input bams: ", bams)
# Out:
# sample:  ['SA2_siC_S11' 'SA2_siC_S2']
# Input bams:  ['SA2_siC_S11_final.bam', 'SA2_siC_S2_final.bam']

# %%
## Apply function to the list of bams filenames
Input_merge_bam(*bams)
# Out:
# '-I SA2_siC_S11_final.bam -I SA2_siC_S2_final.bam'

# %%
## Column needed to match properly different replicates.
## Each entry is a string of (Protein, Condition) joined by "_"
data["Prot_Cond"] = ["_".join((Prot,Cond)) for Prot,Cond in zip(data.Protein,data.Condition)]
# Out:
# array(['input_siC', 'input_siNipbl', 'NiPBL_siC', 'SA1_siC', 'SA2_siC',
#        'SMC1_siC', 'NiPBL_siNipbl', 'SA1_siNipbl', 'SA2_siNipbl',
#        'SMC1_siNipbl'], dtype=object)

# %%
## Check that expand function works as expected
expand( "/align/{Prot_Cond}_final_merged.bam",
            Prot_Cond=data.Prot_Cond.unique())
# Out:
# ['/align/input_siC_final_merged.bam',
#  '/align/input_siNipbl_final_merged.bam',
#  '/align/NiPBL_siC_final_merged.bam',
#  '/align/SA1_siC_final_merged.bam',
#  '/align/SA2_siC_final_merged.bam',
#  '/align/SMC1_siC_final_merged.bam',
#  '/align/NiPBL_siNipbl_final_merged.bam',
#  '/align/SA1_siNipbl_final_merged.bam',
#  '/align/SA2_siNipbl_final_merged.bam',
#  '/align/SMC1_siNipbl_final_merged.bam']

# %%
## Esto es una prueba, quitarlo


" ".join(
    np.unique(
        expand({"/bw/{sample}_RPKM_scaled.bw"},
                       sample=list(filter(None,
                                          [ sampl \
                                    if prot != "input" \
                                    else "" \
         for (sampl,prot) in zip(data.Samples, data.Protein)]
                                 )
                          )
               )
    )
)
# Out:
# '/bw/NiPBL_siC_S4_RPKM_scaled.bw /bw/NiPBL_siNipbl_S8_RPKM_scaled.bw /bw/SA1_siC_S1_RPKM_scaled.bw /bw/SA1_siNipbl_S5_RPKM_scaled.bw /bw/SA2_siC_S11_RPKM_scaled.bw /bw/SA2_siC_S2_RPKM_scaled.bw /bw/SA2_siNipbl_S6_RPKM_scaled.bw /bw/SMC1_siC_S12_RPKM_scaled.bw /bw/SMC1_siC_S3_RPKM_scaled.bw /bw/SMC1_siNipbl_S7_RPKM_scaled.bw'

# %%
data.Samples.unique()
# Out:
# array(['input_siC_S9', 'input_siNipbl_S10', 'NiPBL_siC_S4', 'SA1_siC_S1',
#        'SA2_siC_S11', 'SA2_siC_S2', 'SMC1_siC_S12', 'SMC1_siC_S3',
#        'NiPBL_siNipbl_S8', 'SA1_siNipbl_S5', 'SA2_siNipbl_S6',
#        'SMC1_siNipbl_S7'], dtype=object)

# %%
expand('{a}.gz', a=np.arange(0,10))
# Out:
# ['0.gz',
#  '1.gz',
#  '2.gz',
#  '3.gz',
#  '4.gz',
#  '5.gz',
#  '6.gz',
#  '7.gz',
#  '8.gz',
#  '9.gz']

# %% [markdown]
# ## Filenames and Labels for compute_matrix

# %%
matrixFiles = data.Samples[data.Protein != 'input'].unique()
matrixFiles
# Out:
# array(['NiPBL_siC_S4', 'SA1_siC_S1', 'SA2_siC_S11', 'SA2_siC_S2',
#        'SMC1_siC_S12', 'SMC1_siC_S3', 'NiPBL_siNipbl_S8',
#        'SA1_siNipbl_S5', 'SA2_siNipbl_S6', 'SMC1_siNipbl_S7'],
#       dtype=object)

# %%
import re

# %%
[re.sub("_S.+$","",f) for f in matrixFiles]
# Out:
# ['NiPBL_siC',
#  'SA1_siC',
#  'SA2_siC',
#  'SA2_siC',
#  'SMC1_siC',
#  'SMC1_siC',
#  'NiPBL_siNipbl',
#  'SA1_siNipbl',
#  'SA2_siNipbl',
#  'SMC1_siNipbl']

# %% [markdown]
# ## Find samples to cluster heatmap

# %%
## Find where SA2 protein appears in matr
ix=np.where(np.array(["SA2" in Samp for Samp in matrixFiles ]))[0]
ix=ix+1 # first column is 1 in deeptools but np.where is 0 based
" ".join(ix.astype(str))
# Out:
# '3 4 9'

# %% [markdown]
# ## Motif Enrichment
#
# We are using homer's `findMotifsGenome.pl` script to find e riched motifs between conditions.
# We must be able to

# %%
PEAKSDIR = "/Users/aqo/Desktop/siNipblChipPeaks/unique/"

# %%
## Data frame with .narrowPeak files
naPeak = glob.glob(PEAKSDIR + "*uniquePeaks.bed")
meta=pd.DataFrame(naPeak, columns=["uniqPeakFile"])

# %%
## Extract basename
meta["Basename"]=[re.sub(pattern='^.+/', repl="",string=f) for f in meta.uniqPeakFile]
meta
# Out:
#                                          uniqPeakFile  \
# 0   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 1   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 2   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 3   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 4   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 5   /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 6   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 7   /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 8   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 9   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 10  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 11  /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
#
#                                    Basename
# 0       SMC1_Common_siNipbl_uniquePeaks.bed
# 1        SA1_Common_siNipbl_uniquePeaks.bed
# 2    SMC1_treatOnly_siNipbl_uniquePeaks.bed
# 3     SA1_treatOnly_siNipbl_uniquePeaks.bed
# 4     SA2_treatOnly_siNipbl_uniquePeaks.bed
# 5      NiPBL_Common_siNipbl_uniquePeaks.bed
# 6      SA1_ContOnly_siNipbl_uniquePeaks.bed
# 7    NiPBL_ContOnly_siNipbl_uniquePeaks.bed
# 8        SA2_Common_siNipbl_uniquePeaks.bed
# 9     SMC1_ContOnly_siNipbl_uniquePeaks.bed
# 10     SA2_ContOnly_siNipbl_uniquePeaks.bed
# 11  NiPBL_treatOnly_siNipbl_uniquePeaks.bed

# %%
## EXtract Prot Condition and Rep from Basename
meta[["Protein","uniqueIn","Treatment","tmp"]] = meta["Basename"].str.split("_", expand=True)
meta=meta.drop(columns=['tmp'])

# %%
meta['Sample']=meta.Protein +"_"+meta.uniqueIn+"_"+ meta.Treatment
meta
# Out:
#                                          uniqPeakFile  \
# 0   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 1   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 2   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 3   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 4   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 5   /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 6   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 7   /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 8   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 9   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 10  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 11  /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
#
#                                    Basename Protein   uniqueIn Treatment  \
# 0       SMC1_Common_siNipbl_uniquePeaks.bed    SMC1     Common   siNipbl
# 1        SA1_Common_siNipbl_uniquePeaks.bed     SA1     Common   siNipbl
# 2    SMC1_treatOnly_siNipbl_uniquePeaks.bed    SMC1  treatOnly   siNipbl
# 3     SA1_treatOnly_siNipbl_uniquePeaks.bed     SA1  treatOnly   siNipbl
# 4     SA2_treatOnly_siNipbl_uniquePeaks.bed     SA2  treatOnly   siNipbl
# 5      NiPBL_Common_siNipbl_uniquePeaks.bed   NiPBL     Common   siNipbl
# 6      SA1_ContOnly_siNipbl_uniquePeaks.bed     SA1   ContOnly   siNipbl
# 7    NiPBL_ContOnly_siNipbl_uniquePeaks.bed   NiPBL   ContOnly   siNipbl
# 8        SA2_Common_siNipbl_uniquePeaks.bed     SA2     Common   siNipbl
# 9     SMC1_ContOnly_siNipbl_uniquePeaks.bed    SMC1   ContOnly   siNipbl
# 10     SA2_ContOnly_siNipbl_uniquePeaks.bed     SA2   ContOnly   siNipbl
# 11  NiPBL_treatOnly_siNipbl_uniquePeaks.bed   NiPBL  treatOnly   siNipbl
#
#                      Sample
# 0       SMC1_Common_siNipbl
# 1        SA1_Common_siNipbl
# 2    SMC1_treatOnly_siNipbl
# 3     SA1_treatOnly_siNipbl
# 4     SA2_treatOnly_siNipbl
# 5      NiPBL_Common_siNipbl
# 6      SA1_ContOnly_siNipbl
# 7    NiPBL_ContOnly_siNipbl
# 8        SA2_Common_siNipbl
# 9     SMC1_ContOnly_siNipbl
# 10     SA2_ContOnly_siNipbl
# 11  NiPBL_treatOnly_siNipbl

# %%
## add Background col to know which file use as bg in homer
meta['Background']= [ meta.uniqPeakFile[(meta.Protein == P) & (meta.uniqueIn == 'Common')].values[0] \
                     if (UniqIn != 'Common') else "" \
                     for P,UniqIn in zip(meta.Protein, meta.uniqueIn)]
meta
# Out:
#                                          uniqPeakFile  \
# 0   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 1   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 2   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 3   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 4   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 5   /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 6   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 7   /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 8   /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 9   /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 10  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 11  /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
#
#                                    Basename Protein   uniqueIn Treatment  \
# 0       SMC1_Common_siNipbl_uniquePeaks.bed    SMC1     Common   siNipbl
# 1        SA1_Common_siNipbl_uniquePeaks.bed     SA1     Common   siNipbl
# 2    SMC1_treatOnly_siNipbl_uniquePeaks.bed    SMC1  treatOnly   siNipbl
# 3     SA1_treatOnly_siNipbl_uniquePeaks.bed     SA1  treatOnly   siNipbl
# 4     SA2_treatOnly_siNipbl_uniquePeaks.bed     SA2  treatOnly   siNipbl
# 5      NiPBL_Common_siNipbl_uniquePeaks.bed   NiPBL     Common   siNipbl
# 6      SA1_ContOnly_siNipbl_uniquePeaks.bed     SA1   ContOnly   siNipbl
# 7    NiPBL_ContOnly_siNipbl_uniquePeaks.bed   NiPBL   ContOnly   siNipbl
# 8        SA2_Common_siNipbl_uniquePeaks.bed     SA2     Common   siNipbl
# 9     SMC1_ContOnly_siNipbl_uniquePeaks.bed    SMC1   ContOnly   siNipbl
# 10     SA2_ContOnly_siNipbl_uniquePeaks.bed     SA2   ContOnly   siNipbl
# 11  NiPBL_treatOnly_siNipbl_uniquePeaks.bed   NiPBL  treatOnly   siNipbl
#
#                      Sample                                         Background
# 0       SMC1_Common_siNipbl
# 1        SA1_Common_siNipbl
# 2    SMC1_treatOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 3     SA1_treatOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 4     SA2_treatOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 5      NiPBL_Common_siNipbl
# 6      SA1_ContOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 7    NiPBL_ContOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 8        SA2_Common_siNipbl
# 9     SMC1_ContOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 10     SA2_ContOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 11  NiPBL_treatOnly_siNipbl  /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...

# %%
meta.Background.astype(str)
# Out:
# 0
# 1
# 2     /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 3     /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 4     /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 5
# 6     /Users/aqo/Desktop/siNipblChipPeaks/unique/SA1...
# 7     /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# 8
# 9     /Users/aqo/Desktop/siNipblChipPeaks/unique/SMC...
# 10    /Users/aqo/Desktop/siNipblChipPeaks/unique/SA2...
# 11    /Users/aqo/Desktop/siNipblChipPeaks/unique/NiP...
# Name: Background, dtype: object
